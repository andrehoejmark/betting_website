# %%
import os
import bankid
from bankid import BankIDJSONClient

# %%
client = BankIDJSONClient(certificates=("C:\\Projects\\betting-project\\testing\\certificate.pem",
                                            "C:\\Projects\\betting-project\\testing\key.pem"),
                                            test_server=True)

# %%
x = client.authenticate(end_user_ip='5.240.33.51',
                        personal_number="197306201646")

# %%
print(x)
# Out:
# {'autoStartToken': '36d9eebf-5f39-43ad-a7e1-1de0d6786be4', 'orderRef': 'e0d7a9fc-3062-47c5-bf73-fe64935de250'}

# %%
order_status = client.collect(order_ref="6e72bcad-fca3-4cba-8b05-aeb06dd50477")

# %%
order_status
# Out:
# {'completionData': {'cert': {'notAfter': '1674601199000',
#    'notBefore': '1611442800000'},
#   'device': {'ipAddress': '37.2.12.105'},
#   'ocspResponse': '...',
#   'signature': '...',
#   'user': {'givenName': 'Marianne',
#    'name': 'Marianne Hammar',
#    'personalNumber': '197306201646',
#    'surname': 'Hammar'}},
#  'orderRef': '6e72bcad-fca3-4cba-8b05-aeb06dd50477',
#  'status': 'complete'}

# %%
order_status
# Out:
# {'completionData': {'cert': {'notAfter': '1674601199000',
#    'notBefore': '1611442800000'},
#   'device': {'ipAddress': '37.2.12.105'},
#   'ocspResponse': '...',
#   'signature': '...',
#   'user': {'givenName': 'Marianne',
#    'name': 'Marianne Hammar',
#    'personalNumber': '197306201646',
#    'surname': 'Hammar'}},
#  'orderRef': '6e72bcad-fca3-4cba-8b05-aeb06dd50477',
#  'status': 'complete'}
